# %% [markdown]
# # Module 6 - Data Visualization Using Matplotlib - Hands On 2 - Markers

# %% [raw]
# Step 4: Import matplotlib.pyplot by typing the following code in the notebook and run it by pressing shift + enter

# %%
import matplotlib.pyplot as plt

# %% [raw]
# Step 5: Run the following code to create a plot with markers that look like the addition symbol.

# %%
plt.plot([x for x in range (0, 10)], marker = 'P')

# %% [raw]
# Step 6: Run the following code to create a plot with markers that look like the diamond symbol.

# %%
plt.plot([x for x in range (0, 10)], marker = 'D')
