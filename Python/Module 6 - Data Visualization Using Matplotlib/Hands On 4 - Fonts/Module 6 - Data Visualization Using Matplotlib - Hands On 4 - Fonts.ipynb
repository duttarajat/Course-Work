# %% [markdown]
# # Module 6 - Data Visualization Using Matplotlib - Hands On 4 - Fonts

# %% [raw]
# Step 4: Import matplotlib.pyplot by typing the following code in the notebook and run it by pressing shift + enter

# %%
import matplotlib.pyplot as plt

# %% [raw]
# Step 5: Run the following code to create a plot with a title, xlabel and ylabel with different fonts.

# %%
plt.title('Cube of Numbers from 0 to 9', fontname = 'Comic Sans MS', fontsize = 18)
plt.xlabel('Numbers from 0 to 9', fontname = 'Arial', fontsize = 12)
plt.ylabel('Cube of numbers on X axis', fontname = 'sans-serif', fontsize = 12)
plt.plot([x**3 for x in range (0, 10)], 'cyan', marker = 'P')
