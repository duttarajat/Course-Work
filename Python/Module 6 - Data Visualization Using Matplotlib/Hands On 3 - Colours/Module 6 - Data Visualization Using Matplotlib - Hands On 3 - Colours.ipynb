# %% [markdown]
# # Module 6 - Data Visualization Using Matplotlib - Hands On 3 - Colours

# %% [raw]
# Step 4: Import matplotlib.pyplot by typing the following code in the notebook and run it by pressing shift + enter

# %%
import matplotlib.pyplot as plt

# %% [raw]
# Step 5: Run the following code to create a plot with two lines with different colors.

# %%
plt.plot([x for x in range (0, 10)], 'red', marker = 'P')
plt.plot([x for x in range (9, -1, -1)], 'blue', marker = 'p')
