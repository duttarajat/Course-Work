# %% [markdown]
# # Project _ Housing Price

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#pip install missingno
import missingno as msno
from sklearn.impute import KNNImputer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
df=pd.read_csv('HousingData.csv')
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90    NaN  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99    NaN  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %% [raw]
# # Data Dictionary
#
# CRIM - per capita crime rate by town
# ZN - proportion of residential land zoned for lots over 25,000 sq.ft.
# INDUS - proportion of non-retail business acres per town.
# CHAS - Charles River dummy variable (1 if tract bounds river; 0 otherwise)
# NOX - nitric oxides concentration (parts per 10 million)
# RM - average number of rooms per dwelling
# AGE - proportion of owner-occupied units built prior to 1940
# DIS - weighted distances to five Boston employment centres
# RAD - index of accessibility to radial highways
# TAX - full-value property-tax rate per $10,000
# PTRATIO - pupil-teacher ratio by town
# B - 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
# LSTAT - % lower status of the population
# ##MEDV - Median value of owner-occupied homes in $1000's

# %%
df.describe().T
# Out:
#          count        mean         std        min         25%         50%  \
# CRIM     486.0    3.611874    8.720192    0.00632    0.081900    0.253715
# ZN       486.0   11.211934   23.388876    0.00000    0.000000    0.000000
# INDUS    486.0   11.083992    6.835896    0.46000    5.190000    9.690000
# CHAS     486.0    0.069959    0.255340    0.00000    0.000000    0.000000
# NOX      506.0    0.554695    0.115878    0.38500    0.449000    0.538000
# RM       506.0    6.284634    0.702617    3.56100    5.885500    6.208500
# AGE      486.0   68.518519   27.999513    2.90000   45.175000   76.800000
# DIS      506.0    3.795043    2.105710    1.12960    2.100175    3.207450
# RAD      506.0    9.549407    8.707259    1.00000    4.000000    5.000000
# TAX      506.0  408.237154  168.537116  187.00000  279.000000  330.000000
# PTRATIO  506.0   18.455534    2.164946   12.60000   17.400000   19.050000
# B        506.0  356.674032   91.294864    0.32000  375.377500  391.440000
# LSTAT    486.0   12.715432    7.155871    1.73000    7.125000   11.430000
# MEDV     506.0   22.532806    9.197104    5.00000   17.025000   21.200000
#
#                 75%       max
# CRIM       3.560263   88.9762
# ZN        12.500000  100.0000
# INDUS     18.100000   27.7400
# CHAS       0.000000    1.0000
# NOX        0.624000    0.8710
# RM         6.623500    8.7800
# AGE       93.975000  100.0000
# DIS        5.188425   12.1265
# RAD       24.000000   24.0000
# TAX      666.000000  711.0000
# PTRATIO   20.200000   22.0000
# B        396.225000  396.9000
# LSTAT     16.955000   37.9700
# MEDV      25.000000   50.0000

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     486 non-null    float64
#  1   ZN       486 non-null    float64
#  2   INDUS    486 non-null    float64
#  3   CHAS     486 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      486 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    486 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
round((df.isnull().sum() / df.count() * 100), 2)
# Out:
# CRIM       4.12
# ZN         4.12
# INDUS      4.12
# CHAS       4.12
# NOX        0.00
# RM         0.00
# AGE        4.12
# DIS        0.00
# RAD        0.00
# TAX        0.00
# PTRATIO    0.00
# B          0.00
# LSTAT      4.12
# MEDV       0.00
# dtype: float64

# %%
msno.matrix(df)
plt.show()

# %%
imputer = KNNImputer()
dfi = pd.DataFrame(imputer.fit_transform(df), columns=df.columns)
dfi
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.20  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.90  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.10  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.80  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.20  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...    ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.10  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.70  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.00  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.30  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  78.86  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   7.56  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.38  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
dfi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(14)
# memory usage: 55.5 KB

# %%
msno.matrix(dfi)
plt.show()

# %%
X=dfi.drop(columns='MEDV')
Y=dfi.MEDV

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, train_size=0.75, random_state=1)

# %%
scaler=StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
model=Sequential()
model.add(Dense(13, activation= 'relu', input_dim =13))
model.add(Dropout(rate=0.1))
model.add(Dense(26, activation ='relu'))
model.add(Dropout(rate=0.1))
model.add(Dense(26, activation ='relu'))
model.add(Dropout(rate=0.1))
model.add(Dense(1, activation='linear'))

# %%
model.compile(optimizer='adam', loss='mse')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 13)                182
#
#  dropout (Dropout)           (None, 13)                0
#
#  dense_1 (Dense)             (None, 26)                364
#
#  dropout_1 (Dropout)         (None, 26)                0
#
#  dense_2 (Dense)             (None, 26)                702
#
#  dropout_2 (Dropout)         (None, 26)                0
#
#  dense_3 (Dense)             (None, 1)                 27
#
# =================================================================
# Total params: 1,275
# Trainable params: 1,275
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, Y_train, batch_size=10, epochs=100)
# Out:
# Epoch 1/100
# 38/38 [==============================] - 1s 3ms/step - loss: 523.7519
# Epoch 2/100
# 38/38 [==============================] - 0s 3ms/step - loss: 378.9816
# Epoch 3/100
# 38/38 [==============================] - 0s 3ms/step - loss: 156.5768
# Epoch 4/100
# 38/38 [==============================] - 0s 3ms/step - loss: 74.6597
# Epoch 5/100
# 38/38 [==============================] - 0s 3ms/step - loss: 70.8012
# Epoch 6/100
# 38/38 [==============================] - 0s 3ms/step - loss: 59.6145
# Epoch 7/100
# 38/38 [==============================] - 0s 3ms/step - loss: 54.1672
# Epoch 8/100
# 38/38 [==============================] - 0s 3ms/step - loss: 49.0191
# Epoch 9/100
# 38/38 [==============================] - 0s 4ms/step - loss: 44.9487
# Epoch 10/100
# 38/38 [==============================] - 0s 3ms/step - loss: 48.1859
# Epoch 11/100
# 38/38 [==============================] - 0s 3ms/step - loss: 42.9588
# Epoch 12/100
# 38/38 [==============================] - 0s 3ms/step - loss: 43.6458
# Epoch 13/100
# 38/38 [==============================] - 0s 3ms/step - loss: 40.6455
# Epoch 14/100
# 38/38 [==============================] - 0s 3ms/step - loss: 43.2249
# Epoch 15/100
# 38/38 [==============================] - 0s 3ms/step - loss: 39.3424
# Epoch 16/100
# 38/38 [==============================] - 0s 3ms/step - loss: 36.0781
# Epoch 17/100
# 38/38 [==============================] - 0s 3ms/step - loss: 32.9744
# Epoch 18/100
# 38/38 [==============================] - 0s 3ms/step - loss: 41.1558
# Epoch 19/100
# 38/38 [==============================] - 0s 3ms/step - loss: 31.2652
# Epoch 20/100
# 38/38 [==============================] - 0s 3ms/step - loss: 39.6285
# Epoch 21/100
# 38/38 [==============================] - 0s 3ms/step - loss: 34.4525
# Epoch 22/100
# 38/38 [==============================] - 0s 3ms/step - loss: 31.6390
# Epoch 23/100
# 38/38 [==============================] - 0s 3ms/step - loss: 29.4310
# Epoch 24/100
# 38/38 [==============================] - 0s 3ms/step - loss: 32.2272
# Epoch 25/100
# 38/38 [==============================] - 0s 3ms/step - loss: 33.2592
# Epoch 26/100
# 38/38 [==============================] - 0s 3ms/step - loss: 33.8455
# Epoch 27/100
# 38/38 [==============================] - 0s 3ms/step - loss: 33.3228
# Epoch 28/100
# 38/38 [==============================] - 0s 3ms/step - loss: 30.8252
# Epoch 29/100
# 38/38 [==============================] - 0s 3ms/step - loss: 29.7740
# Epoch 30/100
# 38/38 [==============================] - 0s 3ms/step - loss: 28.6305
# Epoch 31/100
# 38/38 [==============================] - 0s 3ms/step - loss: 26.0622
# Epoch 32/100
# 38/38 [==============================] - 0s 3ms/step - loss: 24.1670
# Epoch 33/100
# 38/38 [==============================] - 0s 3ms/step - loss: 30.0059
# Epoch 34/100
# 38/38 [==============================] - 0s 3ms/step - loss: 25.4379
# Epoch 35/100
# 38/38 [==============================] - 0s 3ms/step - loss: 24.5299
# Epoch 36/100
# 38/38 [==============================] - 0s 3ms/step - loss: 24.7835
# Epoch 37/100
# 38/38 [==============================] - 0s 3ms/step - loss: 30.8134
# Epoch 38/100
# 38/38 [==============================] - 0s 3ms/step - loss: 24.2572
# Epoch 39/100
# 38/38 [==============================] - 0s 3ms/step - loss: 24.7015
# Epoch 40/100
# 38/38 [==============================] - 0s 3ms/step - loss: 30.2275
# Epoch 41/100
# 38/38 [==============================] - 0s 3ms/step - loss: 24.7219
# Epoch 42/100
# 38/38 [==============================] - 0s 3ms/step - loss: 24.5512
# Epoch 43/100
# 38/38 [==============================] - 0s 4ms/step - loss: 24.9541
# Epoch 44/100
# 38/38 [==============================] - 0s 3ms/step - loss: 23.1245
# Epoch 45/100
# 38/38 [==============================] - 0s 3ms/step - loss: 24.6223
# Epoch 46/100
# 38/38 [==============================] - 0s 3ms/step - loss: 21.5614
# Epoch 47/100
# 38/38 [==============================] - 0s 3ms/step - loss: 22.4113
# Epoch 48/100
# 38/38 [==============================] - 0s 3ms/step - loss: 25.0229
# Epoch 49/100
# 38/38 [==============================] - 0s 3ms/step - loss: 24.2007
# Epoch 50/100
# 38/38 [==============================] - 0s 3ms/step - loss: 22.2770
# Epoch 51/100
# 38/38 [==============================] - 0s 3ms/step - loss: 22.6064
# Epoch 52/100
# 38/38 [==============================] - 0s 4ms/step - loss: 22.9495
# Epoch 53/100
# 38/38 [==============================] - 0s 3ms/step - loss: 20.8816
# Epoch 54/100
# 38/38 [==============================] - 0s 3ms/step - loss: 22.0931
# Epoch 55/100
# 38/38 [==============================] - 0s 3ms/step - loss: 23.0239
# Epoch 56/100
# 38/38 [==============================] - 0s 3ms/step - loss: 20.5898
# Epoch 57/100
# 38/38 [==============================] - 0s 4ms/step - loss: 20.4593
# Epoch 58/100
# 38/38 [==============================] - 0s 3ms/step - loss: 21.7168
# Epoch 59/100
# 38/38 [==============================] - 0s 3ms/step - loss: 20.9591
# Epoch 60/100
# 38/38 [==============================] - 0s 3ms/step - loss: 19.8544
# Epoch 61/100
# 38/38 [==============================] - 0s 3ms/step - loss: 25.0349
# Epoch 62/100
# 38/38 [==============================] - 0s 3ms/step - loss: 20.6388
# Epoch 63/100
# 38/38 [==============================] - 0s 3ms/step - loss: 22.3291
# Epoch 64/100
# 38/38 [==============================] - 0s 3ms/step - loss: 17.8846
# Epoch 65/100
# 38/38 [==============================] - 0s 3ms/step - loss: 20.3772
# Epoch 66/100
# 38/38 [==============================] - 0s 3ms/step - loss: 26.0908
# Epoch 67/100
# 38/38 [==============================] - 0s 3ms/step - loss: 18.0778
# Epoch 68/100
# 38/38 [==============================] - 0s 3ms/step - loss: 22.9245
# Epoch 69/100
# 38/38 [==============================] - 0s 3ms/step - loss: 21.6263
# Epoch 70/100
# 38/38 [==============================] - 0s 3ms/step - loss: 23.0059
# Epoch 71/100
# 38/38 [==============================] - 0s 3ms/step - loss: 19.9546
# Epoch 72/100
# 38/38 [==============================] - 0s 3ms/step - loss: 24.5429
# Epoch 73/100
# 38/38 [==============================] - 0s 3ms/step - loss: 20.6918
# Epoch 74/100
# 38/38 [==============================] - 0s 3ms/step - loss: 19.1719
# Epoch 75/100
# 38/38 [==============================] - 0s 3ms/step - loss: 21.8125
# Epoch 76/100
# 38/38 [==============================] - 0s 3ms/step - loss: 22.2946
# Epoch 77/100
# 38/38 [==============================] - 0s 3ms/step - loss: 19.9189
# Epoch 78/100
# 38/38 [==============================] - 0s 3ms/step - loss: 18.2758
# Epoch 79/100
# 38/38 [==============================] - 0s 3ms/step - loss: 23.7689
# Epoch 80/100
# 38/38 [==============================] - 0s 4ms/step - loss: 19.0330
# Epoch 81/100
# 38/38 [==============================] - 0s 3ms/step - loss: 21.1148
# Epoch 82/100
# 38/38 [==============================] - 0s 3ms/step - loss: 18.4659
# Epoch 83/100
# 38/38 [==============================] - 0s 3ms/step - loss: 17.5337
# Epoch 84/100
# 38/38 [==============================] - 0s 3ms/step - loss: 19.6381
# Epoch 85/100
# 38/38 [==============================] - 0s 3ms/step - loss: 21.3756
# Epoch 86/100
# 38/38 [==============================] - 0s 3ms/step - loss: 19.4366
# Epoch 87/100
# 38/38 [==============================] - 0s 4ms/step - loss: 18.6538
# Epoch 88/100
# 38/38 [==============================] - 0s 3ms/step - loss: 19.7756
# Epoch 89/100
# 38/38 [==============================] - 0s 3ms/step - loss: 20.2868
# Epoch 90/100
# 38/38 [==============================] - 0s 3ms/step - loss: 17.2406
# Epoch 91/100
# 38/38 [==============================] - 0s 3ms/step - loss: 14.6594
# Epoch 92/100
# 38/38 [==============================] - 0s 3ms/step - loss: 17.7876
# Epoch 93/100
# 38/38 [==============================] - 0s 3ms/step - loss: 17.3061
# Epoch 94/100
# 38/38 [==============================] - 0s 3ms/step - loss: 20.0448
# Epoch 95/100
# 38/38 [==============================] - 0s 3ms/step - loss: 21.9103
# Epoch 96/100
# 38/38 [==============================] - 0s 3ms/step - loss: 18.1796
# Epoch 97/100
# 38/38 [==============================] - 0s 3ms/step - loss: 19.1713
# Epoch 98/100
# 38/38 [==============================] - 0s 3ms/step - loss: 19.2086
# Epoch 99/100
# 38/38 [==============================] - 0s 3ms/step - loss: 16.4449
# Epoch 100/100
# 38/38 [==============================] - 0s 3ms/step - loss: 20.4223

# %%
plt.plot(model.history.history['loss'], label='Loss')
plt.title('Loss Plot')
plt.show()

# %%
Y_pred = model.predict(X_test)
# Out:
# 4/4 [==============================] - 0s 4ms/step

# %%
print('MAE:', mean_absolute_error(Y_test,Y_pred))
print('MSE:', mean_squared_error(Y_test,Y_pred))
print('RMSE:', np.sqrt(mean_squared_error(Y_test,Y_pred)))
print('R2_Score:', r2_score(Y_test,Y_pred))
# Out:
# MAE: 2.467371820464847
# MSE: 9.682999777240653
# RMSE: 3.111751882339055
# R2_Score: 0.9022496568991238

# %%
plt.scatter(Y_test,Y_pred)
plt.plot(Y_test,Y_test,'r')
plt.show()
